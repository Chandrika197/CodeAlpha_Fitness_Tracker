# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandrika197/CodeAlpha_Fitness_Tracker/blob/main/pe_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/ibm-granite-community/utils
# !pip install langchain-community replicate
# Out:
# Collecting git+https://github.com/ibm-granite-community/utils
#   Cloning https://github.com/ibm-granite-community/utils to /tmp/pip-req-build-vxwoos8t
#   Running command git clone --filter=blob:none --quiet https://github.com/ibm-granite-community/utils /tmp/pip-req-build-vxwoos8t
#   Resolved https://github.com/ibm-granite-community/utils to commit a82df66b8437859de1061f11357ea2c369f242d1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: python_dotenv>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ibm-granite-community-utils==0.1.dev190) (1.2.2)
# Requirement already satisfied: langchain_core>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ibm-granite-community-utils==0.1.dev190) (1.4.9)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ibm-granite-community-utils==0.1.dev190) (4.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (0.10.2)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.5.0->langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core>=1.0.0->ibm-granite-community-utils==0.1.dev190) (2.5.0)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.12/dist-packages (0.4.2)
# Requirement already satisfied: replicate in /usr/local/lib/python3.12/dist-packages (1.0.7)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (1.4.9)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.10.2)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.14.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: httpx<1,>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from replicate) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from replicate) (26.2)
# Requirement already satisfied: pydantic>1.10.7 in /usr/local/lib/python3.12/dist-packages (from replicate) (2.13.4)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from replicate) (4.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->replicate) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->replicate) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->replicate) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.21.0->replicate) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.21.0->replicate) (0.16.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.18)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.17.0)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>1.10.7->replicate) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>1.10.7->replicate) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>1.10.7->replicate) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)

# %%
import os
import replicate
from langchain_community.llms import Replicate
from ibm_granite_community.notebook_utils import get_env_var
import ipywidgets as widgets
from IPython.display import display, Markdown, HTML
# Out:
# /tmp/ipykernel_10344/1439793642.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.llms import Replicate

# %%
# Use the utility function to get from environment or prompt
replicate_api_token = get_env_var("REPLICATE_API_TOKEN")
os.environ["REPLICATE_API_TOKEN"] = replicate_api_token
# Out:
# REPLICATE_API_TOKEN loaded from Google Colab secret.

# %%
# Model configuration - exactly as in reference
MODEL_NAME = "ibm-granite/granite-3.3-8b-instruct"
MAX_TOKENS = 1024
TEMPERATURE = 0.2

# Initialize the model
llm = Replicate(
    model=MODEL_NAME,
    model_kwargs={
        "max_tokens": MAX_TOKENS,
        "temperature": TEMPERATURE
    }
)

print(f"✅ Model initialized: {MODEL_NAME}")
print(f"   Max Tokens: {MAX_TOKENS}")
print(f"   Temperature: {TEMPERATURE}")
# Out:
# ✅ Model initialized: ibm-granite/granite-3.3-8b-instruct
#    Max Tokens: 1024
#    Temperature: 0.2

# %%
# Input To Project: Bulleted, messy, partial notes
input = """Project: Alpha CRM Upgrade — Weekly Update Notes
• Login issue fixed for 80% users, pending bug #3421
• Deployment for Phase 2 pushed from 15th to 19th
• Client appreciated responsiveness
• Risk: insufficient test data for UAT
• Next steps: Dev team to finalize API changes, Testing team to complete regression
• Need to highlight dependency on Data Engineering
"""


print("Sample inputs loaded successfully!")
print("\nYou will use 'input' as the Project Updates in the exercises below.")
# Out:
# Sample inputs loaded successfully!
#
# You will use 'input' as the Project Updates in the exercises below.

# %%
# Direct, zero-shot prompt
zero_shot_prompt = "Write a 120-word weekly project update."

print("🔵 TASK 2: Zero-Shot Prompting")
print("="*60)
print(f"Prompt: {zero_shot_prompt}\n")

# Get response from model
zero_shot_response = llm.invoke(zero_shot_prompt)

print("Response:")
print("-"*60)
print(zero_shot_response)
print("-"*60)
# Out:
# 🔵 TASK 2: Zero-Shot Prompting
# ============================================================
# Prompt: Write a 120-word weekly project update.
# ---------------------------------------------------------------------------
# ReplicateError                            Traceback (most recent call last)
# /tmp/ipykernel_10344/2490749073.py in <cell line: 0>()
#       7
#       8 # Get response from model
# ----> 9 zero_shot_response = llm.invoke(zero_shot_prompt)
#      10
#      11 print("Response:")
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/llms.py in invoke(self, input, config, stop, **kwargs)
#     382         config = ensure_config(config)
#     383         return (
# --> 384             self.generate_prompt(
#     385                 [self._convert_input(input)],
#     386                 stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/llms.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     799     ) -> LLMResult:
#     800         prompt_strings = [p.to_string() for p in prompts]
# --> 801         return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#     802
#     803     @override
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1029                 )
#    1030             ]
# -> 1031             return self._generate_helper(
#    1032                 prompts,
#    1033                 stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     825         try:
#     826             output = (
# --> 827                 self._generate(
#     828                     prompts,
#     829                     stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/llms.py in _generate(self, prompts, stop, run_manager, **kwargs)
#    1544         for prompt in prompts:
#    1545             text = (
# -> 1546                 self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1547                 if new_arg_supported
#    1548                 else self._call(prompt, stop=stop, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/langchain_community/llms/replicate.py in _call(self, prompt, stop, run_manager, **kwargs)
#     139                     completion += chunk.text
#     140         else:
# --> 141             prediction = self._create_prediction(prompt, **kwargs)
#     142             prediction.wait()
#     143             if prediction.status == "failed":
#
# /usr/local/lib/python3.12/dist-packages/langchain_community/llms/replicate.py in _create_prediction(self, prompt, **kwargs)
#     226         # if it's an official model
#     227         if ":" not in self.model:
# --> 228             return replicate_python.models.predictions.create(self.model, input=input_)
#     229         else:
#     230             return replicate_python.predictions.create(
#
# /usr/local/lib/python3.12/dist-packages/replicate/model.py in create(self, model, input, **params)
#     403         body = _create_prediction_body(version=None, input=input, **params)
#     404         extras = _create_prediction_request_params(wait=wait)
# --> 405         resp = self._client._request("POST", path, json=body, **extras)
#     406
#     407         return _json_to_prediction(self._client, resp.json())
#
# /usr/local/lib/python3.12/dist-packages/replicate/client.py in _request(self, method, path, **kwargs)
#      87     def _request(self, method: str, path: str, **kwargs) -> httpx.Response:
#      88         resp = self._client.request(method, path, **kwargs)
# ---> 89         _raise_for_status(resp)
#      90
#      91         return resp
#
# /usr/local/lib/python3.12/dist-packages/replicate/client.py in _raise_for_status(resp)
#     405 def _raise_for_status(resp: httpx.Response) -> None:
#     406     if 400 <= resp.status_code < 600:
# --> 407         raise ReplicateError.from_response(resp)
#
# ReplicateError: ReplicateError Details:
# title: Insufficient credit
# status: 402
# detail: You have insufficient credit to run this model. Go to https://replicate.com/account/billing#billing to purchase credit. Once you purchase credit, please wait a few minutes before trying again.

# %%
# Task-specific prompt with structure
def create_structured_prompt(project_input):
    prompt = f"""Create a 120-word weekly project update for internal stakeholders.
Include: current status, completed tasks, risks, and next steps.

Based on this input:
{project_input}
"""
    return prompt

# Let's use Input A for this task
structured_prompt = create_structured_prompt(input)

print("🟢 TASK 3: Task-Specific Prompt with Structured Instructions")
print("="*60)
print("Prompt:")
print(structured_prompt)
print("\nGenerating response...\n")

# Get response from model
structured_response = llm.invoke(structured_prompt)

print("Response:")
print("-"*60)
print(structured_response)
print("-"*60)

# %%
# Advanced prompt with role, tone, and format
def create_advanced_prompt(project_input):
    prompt = f"""You are a project reporting assistant for an IT services company.

Task: Generate a 120-word weekly project update for internal stakeholders.

Tone: Concise and professional.

Format: Use bullet points for the following sections:
- Current Status
- Completed Tasks
- Risks/Issues
- Next Steps

Input information:
{project_input}

Generate the update now:
"""
    return prompt

# Test with Project Input
advanced_prompt = create_advanced_prompt(input)

print("🟣 TASK 4: Advanced Prompt Engineering")
print("="*60)
print("Prompt:")
print(advanced_prompt)
print("\nGenerating response...\n")

# Get response from model
advanced_response = llm.invoke(advanced_prompt)

print("Response:")
print("-"*60)
print(advanced_response)
print("-"*60)
